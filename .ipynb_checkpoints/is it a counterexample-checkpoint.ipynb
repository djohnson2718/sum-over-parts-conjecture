# %%
var("t,q,t1,t2,X")
R.<z> = PowerSeriesRing(SR)


def S(order, beta):
    return sum((
        z^n*sum(( 
                prod((beta.subs({x: t^mu.leg_length(*c) * q^mu.arm_length(*c)}) for c in mu.cells()))/
                prod((
                    (q^mu.arm_length(*c) - t^(mu.leg_length(*c)+1))*(t^mu.leg_length(*c)-q^(mu.arm_length(*c)+1))
                for c in mu.cells()))
            for mu in Partitions(n)))
    for n in range(order+1))).add_bigoh(order+1)

def Xconst(f):
    return (f/X).residue(X)

def qtsub(f):
    return f.subs({q:exp(t1*X),t:exp(t2*X)})

def b(f):
    return Xconst(qtsub(f))

def check(order,beta):
    logS = S(order,beta).log()
    for i in range(1, order+1):
        print(i,"**",b(logS[i]).simplify_full())
        
def printlogS(order,beta):
    logS = S(order,beta).log()
    for i in range(1,order+1):
        print(i,"**", logS[i].simplify_full().factor())

# %%
S(3, x + x^2)
# Out:
# 1 + (2/((q - 1)*(t - 1)))*z + (-2*(q^2 + q)/((q^2 - 1)*(q - t)*(q - 1)*(t - 1)) + 2*(t^2 + t)/((t^2 - 1)*(q - t)*(q - 1)*(t - 1)))*z^2 + (2*(q^4 + q^2)*(q^2 + q)/((q^3 - 1)*(q^2 - t)*(q^2 - 1)*(q - t)*(q - 1)*(t - 1)) - 2*(t^4 + t^2)*(t^2 + t)/((t^3 - 1)*(t^2 - q)*(t^2 - 1)*(q - t)*(q - 1)*(t - 1)) + 4*(q^2*t^2 + q*t)/((q^2 - t)*(t^2 - q)*(q - 1)^2*(t - 1)^2))*z^3 + O(z^4)

# %%
check(4, x)
# Out:
# 1 ** 1/12*(t1^2 + 3*t1*t2 + t2^2)/(t1*t2)
# 2 ** 1/24*(t1^2 + 3*t1*t2 + t2^2)/(t1*t2)
# 3 ** 1/36*(t1^2 + 3*t1*t2 + t2^2)/(t1*t2)
# 4 ** 1/48*(t1^2 + 3*t1*t2 + t2^2)/(t1*t2)

# %%
check(4,1)
# Out:
# 1 ** 1/12*(t1^2 + 3*t1*t2 + t2^2)/(t1*t2)
# 2 ** -1/24*(t1^2 + 3*t1*t2 + t2^2)/(t1*t2)
# 3 ** 1/36*(t1^2 + 3*t1*t2 + t2^2)/(t1*t2)
# 4 ** -1/48*(t1^2 + 3*t1*t2 + t2^2)/(t1*t2)

# %%
check(4,x^2)
# Out:
# 1 ** 1/12*(t1^2 + 3*t1*t2 + t2^2)/(t1*t2)
# 2 ** -1/24*(t1^2 + 3*t1*t2 + t2^2)/(t1*t2)
# 3 ** 1/36*(t1^2 + 3*t1*t2 + t2^2)/(t1*t2)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-234f9d0e88c9> in <module>()
# ----> 1 check(Integer(4),x**Integer(2))
#
# <ipython-input-4-1adaf3101f92> in check(order, beta)
#      25     logS = S(order,beta).log()
#      26     for i in range(Integer(1), order+Integer(1)):
# ---> 27         print(i,"**",b(logS[i]).simplify_full())
#      28
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression.simplify_full (build/cythonized/sage/symbolic/expression.cpp:51205)()
#    9990         x = self
#    9991         x = x.simplify_factorial()
# -> 9992         x = x.simplify_rectform()
#    9993         x = x.simplify_trig()
#    9994         x = x.simplify_rational()
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression.simplify_rectform (build/cythonized/sage/symbolic/expression.cpp:52650)()
#   10141
#   10142         """
# > 10143         simplified_expr = self.rectform()
#   10144
#   10145         if complexity_measure is None:
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression.rectform (build/cythonized/sage/symbolic/expression.cpp:50714)()
#    9822
#    9823         """
# -> 9824         return self.maxima_methods().rectform()
#    9825
#    9826     def unhold(self, exclude=None):
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/maxima_wrapper.py in __getattr__(self, s)
#      87         """
#      88         if self._maxima_exp is None:
# ---> 89             self._maxima_exp = self._exp._maxima_()
#      90         if s[0] == '_':
#      91             return getattr(self._maxima_exp, s)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression._maxima_ (build/cythonized/sage/symbolic/expression.cpp:7809)()
#     853             # Maybe not such a great idea because the "default" interface is another one
#     854             from sage.calculus.calculus import maxima
# --> 855             return super(Expression, self)._interface_(maxima)
#     856         else:
#     857             return super(Expression, self)._interface_(session)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/structure/sage_object.pyx in sage.structure.sage_object.SageObject._interface_ (build/cythonized/sage/structure/sage_object.c:5439)()
#     676                 s = init_func(I)
#     677             else:
# --> 678                 s = init_func()
#     679         else:
#     680             try:
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/structure/sage_object.pyx in sage.structure.sage_object.SageObject._maxima_lib_init_ (build/cythonized/sage/structure/sage_object.c:8328)()
#     793
#     794     def _maxima_lib_init_(self):
# --> 795         return self._maxima_init_()
#     796
#     797     def _magma_init_(self, magma):
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/structure/sage_object.pyx in sage.structure.sage_object.SageObject._maxima_init_ (build/cythonized/sage/structure/sage_object.c:8099)()
#     786         import sage.interfaces.maxima
#     787         I = sage.interfaces.maxima.maxima
# --> 788         return self._interface_init_(I)
#     789
#     790     def _maxima_lib_(self, G=None):
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression._interface_init_ (build/cythonized/sage/symbolic/expression.cpp:7980)()
#     890         """
#     891         from sage.symbolic.expression_conversions import InterfaceInit
# --> 892         return InterfaceInit(I)(self)
#     893
#     894     def _gap_init_(self):
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     213
#     214         if operator in arithmetic_operators:
# --> 215             if getattr(self, 'use_fake_div', False) and (operator is _operator.mul or operator is mul_vararg):
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
#
# src/cysignals/signals.pyx in cysignals.signals.python_check_interrupt()
#
# KeyboardInterrupt:

# %%
printlogS(4,1)
# Out:
# 1 ** 1/((q - 1)*(t - 1))
# 2 ** -1/2/((q + 1)*(q - 1)*(t + 1)*(t - 1))
# 3 ** 1/3/((q^2 + q + 1)*(t^2 + t + 1)*(q - 1)*(t - 1))
# 4 ** -1/4/((q^2 + 1)*(t^2 + 1)*(q + 1)*(q - 1)*(t + 1)*(t - 1))

# %%
printlogS(4,x)
# Out:
# 1 ** 1/((q - 1)*(t - 1))
# 2 ** 1/2/((q + 1)*(q - 1)*(t + 1)*(t - 1))
# 3 ** 1/3/((q^2 + q + 1)*(t^2 + t + 1)*(q - 1)*(t - 1))
# 4 ** 1/4/((q^2 + 1)*(t^2 + 1)*(q + 1)*(q - 1)*(t + 1)*(t - 1))

# %%
printlogS(4,x^2)
# Out:
# 1 ** 1/((q - 1)*(t - 1))
# 2 ** -1/2/((q + 1)*(q - 1)*(t + 1)*(t - 1))
# 3 ** 1/3/((q^2 + q + 1)*(t^2 + t + 1)*(q - 1)*(t - 1))
# 4 ** -1/4/((q^2 + 1)*(t^2 + 1)*(q + 1)*(q - 1)*(t + 1)*(t - 1))

# %%
printlogS(4,x^3)
# Out:
# 1 ** 1/((q - 1)*(t - 1))
# 2 ** -1/2*(2*q*t + 2*q + 2*t + 1)/((q + 1)*(q - 1)*(t + 1)*(t - 1))
# 3 ** 1/3*(3*q^3*t^2 + 3*q^2*t^3 + 3*q^3*t + 6*q^2*t^2 + 3*q*t^3 + 3*q^3 + 6*q^2*t + 6*q*t^2 + 3*t^3 + 3*q^2 + 6*q*t + 3*t^2 + 3*q + 3*t + 1)/((q^2 + q + 1)*(t^2 + t + 1)*(q - 1)*(t - 1))
# 4 ** -1/4*(4*q^6*t^3 + 4*q^5*t^4 + 4*q^4*t^5 + 4*q^3*t^6 + 4*q^6*t^2 + 8*q^5*t^3 + 12*q^4*t^4 + 8*q^3*t^5 + 4*q^2*t^6 + 4*q^6*t + 8*q^5*t^2 + 20*q^4*t^3 + 20*q^3*t^4 + 8*q^2*t^5 + 4*q*t^6 + 4*q^6 + 8*q^5*t + 20*q^4*t^2 + 28*q^3*t^3 + 20*q^2*t^4 + 8*q*t^5 + 4*t^6 + 4*q^5 + 16*q^4*t + 24*q^3*t^2 + 24*q^2*t^3 + 16*q*t^4 + 4*t^5 + 8*q^4 + 20*q^3*t + 22*q^2*t^2 + 20*q*t^3 + 8*t^4 + 8*q^3 + 16*q^2*t + 16*q*t^2 + 8*t^3 + 6*q^2 + 12*q*t + 6*t^2 + 4*q + 4*t + 1)/((q^2 + 1)*(t^2 + 1)*(q + 1)*(q - 1)*(t + 1)*(t - 1))

# %%
printlogS(4,x^4)
# Out:
# 1 ** 1/((q - 1)*(t - 1))
# 2 ** -1/2*(2*q^2*t + 2*q*t^2 + 2*q^2 + 4*q*t + 2*t^2 + 2*q + 2*t + 1)/((q + 1)*(q - 1)*(t + 1)*(t - 1))
# 3 ** 1/3*(3*q^6*t^2 + 3*q^5*t^3 + 3*q^4*t^4 + 3*q^3*t^5 + 3*q^2*t^6 + 3*q^6*t + 6*q^5*t^2 + 9*q^4*t^3 + 9*q^3*t^4 + 6*q^2*t^5 + 3*q*t^6 + 3*q^6 + 6*q^5*t + 15*q^4*t^2 + 18*q^3*t^3 + 15*q^2*t^4 + 6*q*t^5 + 3*t^6 + 3*q^5 + 12*q^4*t + 21*q^3*t^2 + 21*q^2*t^3 + 12*q*t^4 + 3*t^5 + 6*q^4 + 15*q^3*t + 24*q^2*t^2 + 15*q*t^3 + 6*t^4 + 6*q^3 + 15*q^2*t + 15*q*t^2 + 6*t^3 + 6*q^2 + 9*q*t + 6*t^2 + 3*q + 3*t + 1)/((q^2 + q + 1)*(t^2 + t + 1)*(q - 1)*(t - 1))
# 4 ** -1/4*(4*q^12*t^3 + 4*q^11*t^4 + 4*q^10*t^5 + 4*q^9*t^6 + 4*q^8*t^7 + 4*q^7*t^8 + 4*q^6*t^9 + 4*q^5*t^10 + 4*q^4*t^11 + 4*q^3*t^12 + 4*q^12*t^2 + 8*q^11*t^3 + 12*q^10*t^4 + 12*q^9*t^5 + 12*q^8*t^6 + 12*q^7*t^7 + 12*q^6*t^8 + 12*q^5*t^9 + 12*q^4*t^10 + 8*q^3*t^11 + 4*q^2*t^12 + 4*q^12*t + 8*q^11*t^2 + 20*q^10*t^3 + 28*q^9*t^4 + 32*q^8*t^5 + 32*q^7*t^6 + 32*q^6*t^7 + 32*q^5*t^8 + 28*q^4*t^9 + 20*q^3*t^10 + 8*q^2*t^11 + 4*q*t^12 + 4*q^12 + 8*q^11*t + 20*q^10*t^2 + 40*q^9*t^3 + 56*q^8*t^4 + 64*q^7*t^5 + 64*q^6*t^6 + 64*q^5*t^7 + 56*q^4*t^8 + 40*q^3*t^9 + 20*q^2*t^10 + 8*q*t^11 + 4*t^12 + 4*q^11 + 16*q^10*t + 36*q^9*t^2 + 68*q^8*t^3 + 96*q^7*t^4 + 108*q^6*t^5 + 108*q^5*t^6 + 96*q^4*t^7 + 68*q^3*t^8 + 36*q^2*t^9 + 16*q*t^10 + 4*t^11 + 8*q^10 + 28*q^9*t + 60*q^8*t^2 + 108*q^7*t^3 + 144*q^6*t^4 + 160*q^5*t^5 + 144*q^4*t^6 + 108*q^3*t^7 + 60*q^2*t^8 + 28*q*t^9 + 8*t^10 + 12*q^9 + 40*q^8*t + 88*q^7*t^2 + 148*q^6*t^3 + 192*q^5*t^4 + 192*q^4*t^5 + 148*q^3*t^6 + 88*q^2*t^7 + 40*q*t^8 + 12*t^9 + 16*q^8 + 56*q^7*t + 116*q^6*t^2 + 184*q^5*t^3 + 216*q^4*t^4 + 184*q^3*t^5 + 116*q^2*t^6 + 56*q*t^7 + 16*t^8 + 20*q^7 + 68*q^6*t + 136*q^5*t^2 + 192*q^4*t^3 + 192*q^3*t^4 + 136*q^2*t^5 + 68*q*t^6 + 20*t^7 + 24*q^6 + 76*q^5*t + 138*q^4*t^2 + 164*q^3*t^3 + 138*q^2*t^4 + 76*q*t^5 + 24*t^6 + 24*q^5 + 72*q^4*t + 112*q^3*t^2 + 112*q^2*t^3 + 72*q*t^4 + 24*t^5 + 22*q^4 + 56*q^3*t + 76*q^2*t^2 + 56*q*t^3 + 22*t^4 + 16*q^3 + 36*q^2*t + 36*q*t^2 + 16*t^3 + 10*q^2 + 16*q*t + 10*t^2 + 4*q + 4*t + 1)/((q^2 + 1)*(t^2 + 1)*(q + 1)*(q - 1)*(t + 1)*(t - 1))

# %%
check(3,x^3)
# Out:
# 1 ** 1/12*(t1^2 + 3*t1*t2 + t2^2)/(t1*t2)
# 2 ** -1/24*(t1^2 + 3*t1*t2 + t2^2)/(t1*t2)
# 3 ** 1/36*(7*t1^2 - 15*t1*t2 + 7*t2^2)/(t1*t2)

# %%
check(3, x + x^2)
# Out:
# 1 ** 1/6*(t1^2 + 3*t1*t2 + t2^2)/(t1*t2)
# 2 ** 0
# 3 ** 1/360*(73*t1^4 + 30*t1^3*t2 - 557*t1^2*t2^2 + 30*t1*t2^3 + 73*t2^4)/(2*t1^3*t2 - 5*t1^2*t2^2 + 2*t1*t2^3)

# %%
check(3, x + 2*x^2)
# Out:
# 1 ** 1/4*(t1^2 + 3*t1*t2 + t2^2)/(t1*t2)
# 2 ** -1/8*(t1^2 + 3*t1*t2 + t2^2)/(t1*t2)
# 3 ** 1/120*(93*t1^4 + 40*t1^3*t2 - 667*t1^2*t2^2 + 40*t1*t2^3 + 93*t2^4)/(2*t1^3*t2 - 5*t1^2*t2^2 + 2*t1*t2^3)

# %%
check(3, exp(x)-1)
# Out:
# 1 ** 1/12*(t1^2*(e - 1) + 3*t1*t2*(e - 1) + t2^2*(e - 1))/(t1*t2)
# 2 ** -1/48*(t1^2*(e^2 - 3*e + 2) + t2^2*(e^2 - 3*e + 2) + t1*t2*(e^2 - 7*e + 6))/(t1*t2)
# 3 ** -1/2160*(t1^3*t2*(2271*e^3 - 6370*e^2 + 4039*e + 60) + t1*t2^3*(2271*e^3 - 6370*e^2 + 4039*e + 60) + 11*t1^2*t2^2*(237*e^3 - 953*e^2 + 776*e - 60) - t1^4*(171*e^3 + 146*e^2 - 197*e - 120) - t2^4*(171*e^3 + 146*e^2 - 197*e - 120))/(2*t1^3*t2 - 5*t1^2*t2^2 + 2*t1*t2^3)

# %%
check(3, 3*x)
# Out:
# 1 ** 1/4*(t1^2 + 3*t1*t2 + t2^2)/(t1*t2)
# 2 ** 3/8*(t1^2 + 3*t1*t2 + t2^2)/(t1*t2)
# 3 ** 3/4*(t1^2 + 3*t1*t2 + t2^2)/(t1*t2)

# %%
check_all(2,6)
# Out:
# 2 ** 1/1440*(3*t1^4 + 120*t1^3*t2 + 305*t1^2*t2^2 + 120*t1*t2^3 + 3*t2^4)/(t1^2*t2^2)
# 3 ** -1/181440*(32*t1^6 - 378*t1^5*t2 - 15939*t1^4*t2^2 - 38430*t1^3*t2^3 - 15939*t1^2*t2^4 - 378*t1*t2^5 + 32*t2^6)/(t1^3*t2^3)
# 4 ** -1/87091200*(995*t1^8 + 45060*t1^7*t2 - 18940*t1^6*t2^2 - 8164170*t1^5*t2^3 - 19640607*t1^4*t2^4 - 8164170*t1^3*t2^5 - 18940*t1^2*t2^6 + 45060*t1*t2^7 + 995*t2^8)/(t1^4*t2^4)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-ed00b6a2a999> in <module>()
# ----> 1 check_all(Integer(2),Integer(6))
#
# <ipython-input-12-e25184fe531d> in check_all(start, end)
#      27 def check_all(start,end):
#      28     for n in range(start,end+Integer(1)):
# ---> 29         print(n,"**", check(n))
#
# <ipython-input-12-e25184fe531d> in check(n)
#      23
#      24 def check(n):
# ---> 25     return b(S(n)).simplify_full()
#      26
#      27 def check_all(start,end):
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression.simplify_full (build/cythonized/sage/symbolic/expression.cpp:51178)()
#    9989         """
#    9990         x = self
# -> 9991         x = x.simplify_factorial()
#    9992         x = x.simplify_rectform()
#    9993         x = x.simplify_trig()
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression.simplify_factorial (build/cythonized/sage/symbolic/expression.cpp:54162)()
#   10472
#   10473         """
# > 10474         return self.parent()(self._maxima_().makefact().factcomb().minfactorial())
#   10475
#   10476     factorial_simplify = simplify_factorial
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression._maxima_ (build/cythonized/sage/symbolic/expression.cpp:7809)()
#     853             # Maybe not such a great idea because the "default" interface is another one
#     854             from sage.calculus.calculus import maxima
# --> 855             return super(Expression, self)._interface_(maxima)
#     856         else:
#     857             return super(Expression, self)._interface_(session)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/structure/sage_object.pyx in sage.structure.sage_object.SageObject._interface_ (build/cythonized/sage/structure/sage_object.c:5439)()
#     676                 s = init_func(I)
#     677             else:
# --> 678                 s = init_func()
#     679         else:
#     680             try:
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/structure/sage_object.pyx in sage.structure.sage_object.SageObject._maxima_lib_init_ (build/cythonized/sage/structure/sage_object.c:8328)()
#     793
#     794     def _maxima_lib_init_(self):
# --> 795         return self._maxima_init_()
#     796
#     797     def _magma_init_(self, magma):
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/structure/sage_object.pyx in sage.structure.sage_object.SageObject._maxima_init_ (build/cythonized/sage/structure/sage_object.c:8099)()
#     786         import sage.interfaces.maxima
#     787         I = sage.interfaces.maxima.maxima
# --> 788         return self._interface_init_(I)
#     789
#     790     def _maxima_lib_(self, G=None):
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression._interface_init_ (build/cythonized/sage/symbolic/expression.cpp:7980)()
#     890         """
#     891         from sage.symbolic.expression_conversions import InterfaceInit
# --> 892         return InterfaceInit(I)(self)
#     893
#     894     def _gap_init_(self):
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     216                 div = self.get_fake_div(ex)
#     217                 return self.arithmetic(div, div.operator())
# --> 218             return self.arithmetic(ex, operator)
#     219         elif operator in relation_operators:
#     220             return self.relation(ex, operator)
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in arithmetic(self, ex, operator)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in <listcomp>(.0)
#     623             '(_SAGE_VAR_x)+(2)'
#     624         """
# --> 625         args = ["(%s)"%self(op) for op in ex.operands()]
#     626         return arithmetic_operators[operator].join(args)
#     627
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in __call__(self, ex)
#     210         operator = ex.operator()
#     211         if operator is None:
# --> 212             return self.symbol(ex)
#     213
#     214         if operator in arithmetic_operators:
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/symbolic/expression_conversions.py in symbol(self, ex)
#     428         """
#     429         if self.interface.name()=='maxima':
# --> 430             return '_SAGE_VAR_'+repr(SR(ex))
#     431         else:
#     432             return repr(SR(ex))
#
# src/cysignals/signals.pyx in cysignals.signals.python_check_interrupt()
#
# KeyboardInterrupt:
